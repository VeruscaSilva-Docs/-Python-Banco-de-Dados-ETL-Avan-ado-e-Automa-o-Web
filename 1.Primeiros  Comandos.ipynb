# %% [markdown]
# texto acima serve para armAZENAR VARIAVEL

# %% [markdown]
# Mostra resultado

# %%
nome = 'verusca'
nome1 = 'ana'
nome2 = 'paula'
nome3 = 'agatha'
nome4 = 'viviam'

# %% [markdown]
# ## variaveis

# %%
print(nome)
print(nome1)
print(nome2)
print(nome3)
print(nome4)
# Out:
# verusca
# ana
# paula
# agatha
# viviam

# %% [markdown]
# resultado 2
